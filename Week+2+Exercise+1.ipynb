# %% [markdown]
# Your Name: Kieran Fitzmaurice

# %% [markdown]
# The (x,y,z) positions (in meters) and velocities (in m/s) of 30 molecules in an ideal gas are provided to you in two lists of tuples. Your task is to calculate the new positions of the molecules 0.002 seconds later, assuming that there are no collisions between the molecules. Put your result in a new list of tuples called `new_positions`. Print that list.

# %%
positions = [(0.9359, 0.6438, 0.9359), (0.5858, 0.8401, 0.5858), (0.5941, 0.356, 0.5941),
             (0.5682, 0.7196, 0.5682), (0.0846, 0.2228, 0.0846), (0.9492, 0.768, 0.9492),
             (0.8077, 0.1583, 0.8077), (0.6962, 0.417, 0.6962), (0.8428, 0.6632, 0.8428),
             (0.8094, 0.2184, 0.8094), (0.808, 0.6979, 0.808), (0.4137, 0.6752, 0.4137),
             (0.9117, 0.1179, 0.9117), (0.924, 0.472, 0.924), (0.6214, 0.9175, 0.6214),
             (0.3156, 0.8483, 0.3156), (0.6571, 0.1385, 0.6571), (0.7023, 0.6369, 0.7023),
             (0.862, 0.7186, 0.862), (0.4235, 0.4044, 0.4235), (0.7867, 0.9759, 0.7867),
             (0.2067, 0.9657, 0.2067), (0.7957, 0.2696, 0.7957), (0.1935, 0.3537, 0.1935),
             (0.7554, 0.1381, 0.7554), (0.0656, 0.1298, 0.0656), (0.3923, 0.1867, 0.3923),
             (0.3929, 0.581, 0.3929), (0.8358, 0.8674, 0.8358), (0.6739, 0.5666, 0.6739)]

velocities = [(23.3, 28.7, 443.2), (185.2, 7.6, 124.9), (43.4, 241.5, 96.2),
              (364.9, 27.5, 12.3), (378.1, 463.9, 117.5), (356.7, 402.1, 333.5),
              (57.3, 243.6, 156.7), (160.1, 74.6, 211.9), (86.4, 447.1, 455.1),
              (152.5, 46.3, 393.9), (244.5, 156.5, 355.1), (38.4, 251.2, 252.1),
              (442.9, 417.3, 296.6), (244.7, 118.0, 361.2), (11.2, 207.1, 160.7),
              (262.0, 32.6, 326.7), (454.2, 421.4, 402.0), (455.9, 64.0, 36.6),
              (212.8, 445.9, 432.2), (437.2, 60.8, 113.2), (147.4, 210.7, 411.5),
              (321.0, 481.1, 105.2), (298.6, 28.4, 449.2), (484.2, 1.4, 407.8),
              (221.6, 205.7, 410.5), (369.0, 106.1, 459.3), (477.1, 342.8, 397.9),
              (205.1, 73.9, 16.3), (428.9, 146.6, 201.6), (4.6, 3.9, 148.1)]

# %%
timestep = 0.002 

n = len(positions)
new_positions = [None]*n     #Declare empty list for new positions

for i in range(n):
    m = len(positions[i])
    new_coords = [None]*m    #Declare empty list for new coordinates
    for j in range(m):
        new_coords[j] = positions[i][j] + velocities[i][j]*timestep #update coordinates
    new_coords = tuple(new_coords) #convert list into tuple
    new_positions[i] = new_coords  #make list of tuples

for i in new_positions:
    print(i)
# Out:
# (0.9824999999999999, 0.7012, 1.8222999999999998)
# (0.9561999999999999, 0.8553, 0.8356)
# (0.6809, 0.839, 0.7865)
# (1.298, 0.7746000000000001, 0.5928)
# (0.8408000000000001, 1.1505999999999998, 0.3196)
# (1.6626, 1.5722, 1.6162)
# (0.9223, 0.6455, 1.1211)
# (1.0164, 0.5662, 1.12)
# (1.0156, 1.5574000000000001, 1.7530000000000001)
# (1.1144, 0.311, 1.5972)
# (1.2970000000000002, 1.0109, 1.5182000000000002)
# (0.4905, 1.1776, 0.9178999999999999)
# (1.7974999999999999, 0.9525, 1.5049000000000001)
# (1.4134, 0.708, 1.6464)
# (0.6437999999999999, 1.3317, 0.9427999999999999)
# (0.8396, 0.9135000000000001, 0.969)
# (1.5655000000000001, 0.9813000000000001, 1.4611)
# (1.6141, 0.7649, 0.7755000000000001)
# (1.2876, 1.6103999999999998, 1.7264)
# (1.2978999999999998, 0.526, 0.6499)
# (1.0815, 1.3973, 1.6097000000000001)
# (0.8487, 1.9279000000000002, 0.4171)
# (1.3929, 0.3264, 1.6941)
# (1.1619000000000002, 0.35650000000000004, 1.0091)
# (1.1985999999999999, 0.5495, 1.5764)
# ...
